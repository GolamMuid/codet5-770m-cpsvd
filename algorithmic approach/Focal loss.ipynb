# %%
"""
Cross-Project Vulnerability Detection (Focal Loss Version)
----------------------------------------------------------
Train on Debian → Test on Chrome
Handles class imbalance using Focal Loss in neural network
"""

# =========================================================
# Imports
# =========================================================

import os
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    recall_score,
    precision_score,
    roc_auc_score,
    f1_score,
    confusion_matrix
)
from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import Callback

warnings.filterwarnings("ignore")

# =========================================================
# TensorFlow Configuration
# =========================================================

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

tf.config.run_functions_eagerly(True)

tf.config.threading.set_inter_op_parallelism_threads(0)
tf.config.threading.set_intra_op_parallelism_threads(0)

os.environ["OMP_NUM_THREADS"] = "8"

# =========================================================
# Progress Logger
# =========================================================

class BatchLogger(Callback):
    def on_train_batch_begin(self, batch, logs=None):
        if batch % 50 == 0:
            print(f"Processing batch {batch}")

# =========================================================
# Reproducibility
# =========================================================

seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

os.environ["PYTHONHASHSEED"] = str(seed)

# =========================================================
# Original Configuration
# =========================================================

EPOCHS_INITIAL = 50
EPOCHS_RETRAIN = 30

BATCH_SIZE_INITIAL = 64
BATCH_SIZE_RETRAIN = 32

LEARNING_RATE = 1e-5
NUM_ITERATIONS = 3

# =========================================================
# Focal Loss Definition
# =========================================================

def focal_loss(alpha=0.25, gamma=2.0):
    """
    Binary Focal Loss for imbalanced datasets.
    """
    def focal_loss_fixed(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1-1e-7)  # avoid log(0)
        cross_entropy = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        weight = alpha * tf.pow(1 - y_pred, gamma) * y_true + (1 - alpha) * tf.pow(y_pred, gamma) * (1 - y_true)
        loss = weight * cross_entropy
        return tf.reduce_mean(loss)
    return focal_loss_fixed

# =========================================================
# Neural Network
# =========================================================

def create_neural_network(input_dim: int):

    model = Sequential([
        Dense(256, activation="relu", input_dim=input_dim),
        Dropout(0.2),

        Dense(128, activation="relu"),
        Dropout(0.2),

        Dense(64, activation="relu"),
        Dropout(0.2),

        Dense(32, activation="relu"),
        Dropout(0.2),

        Dense(16, activation="relu"),

        Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss=focal_loss(alpha=0.25, gamma=2.0),
        metrics=["accuracy"]
    )

    return model

# =========================================================
# Semi-supervised Transfer Learning
# =========================================================

def semi_supervised_transfer_learning(x_train, y_train, x_test):

    model = create_neural_network(x_train.shape[1])

    print("\nTraining Neural Network on Debian (Focal Loss)...")

    model.fit(
        x_train,
        y_train,
        epochs=EPOCHS_INITIAL,
        batch_size=BATCH_SIZE_INITIAL,
        validation_split=0.2,
        callbacks=[BatchLogger()],
        verbose=1
    )

    print("\nGenerating pseudo labels for Chrome dataset...")

    y_pred = model.predict(x_test, verbose=0)
    y_pred_binary = (y_pred > 0.5).astype(int).flatten()

    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))

    print("\nRetraining model with pseudo-labelled Chrome data...")

    model.fit(
        x_train_aug,
        y_train_aug,
        epochs=EPOCHS_RETRAIN,
        batch_size=BATCH_SIZE_RETRAIN,
        verbose=1
    )

    return model, y_pred.flatten()

# =========================================================
# XGBoost
# =========================================================

def train_base_model_xgb(x_train, y_train):

    # Compute scale_pos_weight for XGBoost
    neg = np.sum(y_train == 0)
    pos = np.sum(y_train == 1)
    scale_pos_weight = neg / pos

    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        use_label_encoder=False,
        eval_metric="logloss",
        scale_pos_weight=scale_pos_weight
    )

    model.fit(x_train, y_train)

    return model

# =========================================================
# Main
# =========================================================

def main():

    print("\n=== Training on Debian → Testing on Chrome (Focal Loss) ===")

    # -----------------------------------------------------
    # Load Embeddings (adjust paths if needed)
    # -----------------------------------------------------

    # dataset_dir = os.path.join(os.path.dirname(__file__), "..", "dataset")

    deb_emb = np.load("../dataset/debian_embeddings.npy")
    deb_lbl = np.load("../dataset/debian_labels.npy")

    chr_emb = np.load("../dataset/chrome_embeddings.npy")
    chr_lbl = np.load("../dataset/chrome_labels.npy")

    deb_emb = deb_emb.astype(np.float32)
    chr_emb = chr_emb.astype(np.float32)

    deb_lbl = deb_lbl.astype(np.float32)
    chr_lbl = chr_lbl.astype(np.float32)

    print("Debian dataset shape:", deb_emb.shape)
    print("Chrome dataset shape:", chr_emb.shape)

    # -----------------------------------------------------
    # Normalize
    # -----------------------------------------------------

    scaler = StandardScaler()

    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    # -----------------------------------------------------
    # Ensemble Training
    # -----------------------------------------------------

    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in range(NUM_ITERATIONS):

        print(f"\n=== Ensemble Iteration {i+1}/{NUM_ITERATIONS} ===")

        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb,
            deb_lbl,
            chr_emb
        )

        print("\nTraining XGBoost model...")

        model_xgb = train_base_model_xgb(
            deb_emb,
            deb_lbl
        )

        print("Predicting Chrome dataset...")

        model_xgb_pred = model_xgb.predict(chr_emb)

        ensemble_predictions += model_xgb_pred

    # -----------------------------------------------------
    # Average Predictions
    # -----------------------------------------------------

    ensemble_avg = ensemble_predictions / NUM_ITERATIONS
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    # -----------------------------------------------------
    # Metrics
    # -----------------------------------------------------

    accuracy = accuracy_score(chr_lbl, y_pred_final)
    recall = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc = roc_auc_score(chr_lbl, ensemble_avg)
    f1 = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()

    g_mean = np.sqrt(tp / (tp + fn))
    pf = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:  {accuracy:.3f}")
    print(f"Precision: {precision:.3f}")
    print(f"Recall:    {recall:.3f}")
    print(f"F1-score:  {f1:.3f}")
    print(f"AUC:       {auc:.3f}")
    print(f"G-mean:    {g_mean:.3f}")
    print(f"PF value:  {pf:.3f}")

    print("\nConfusion Matrix:")
    print(f"TN: {tn}")
    print(f"FP: {fp}")
    print(f"FN: {fn}")
    print(f"TP: {tp}")

    # -----------------------------------------------------
    # Plot Confusion Matrix
    # -----------------------------------------------------

    cm = confusion_matrix(chr_lbl, y_pred_final)

    plt.figure(figsize=(6, 5))
    plt.imshow(cm, interpolation="nearest")
    plt.title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar()
    tick_marks = np.arange(2)
    plt.xticks(tick_marks, ["Non-Vulnerable", "Vulnerable"])
    plt.yticks(tick_marks, ["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            plt.text(j, i, cm[i, j], ha="center", va="center")

    plt.ylabel("Actual Label")
    plt.xlabel("Predicted Label")
    plt.tight_layout()
    plt.show()

# =========================================================

if __name__ == "__main__":
    main()
# Out:
# === Training on Debian → Testing on Chrome (Focal Loss) ===
# Debian dataset shape: (18298, 1024)
# Chrome dataset shape: (4436, 1024)
#
# === Ensemble Iteration 1/3 ===
#
# Training Neural Network on Debian (Focal Loss)...
# Epoch 1/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5737 - loss: 0.1280Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6007 - loss: 0.1227Processing batch 100
# 147/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6268 - loss: 0.1180Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6519 - loss: 0.1132Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7556 - loss: 0.0911 - val_accuracy: 0.9317 - val_loss: 0.0463
# Epoch 2/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8852 - loss: 0.0546Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8870 - loss: 0.0533Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8881 - loss: 0.0521Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8897 - loss: 0.0510Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.8975 - loss: 0.0461 - val_accuracy: 0.9333 - val_loss: 0.0293
# Epoch 3/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9087 - loss: 0.0389Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9097 - loss: 0.0385Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9097 - loss: 0.0384Processing batch 150
# 197/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9100 - loss: 0.0383Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9113 - loss: 0.0374 - val_accuracy: 0.9333 - val_loss: 0.0270
# Epoch 4/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9180 - loss: 0.0361Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9181 - loss: 0.0355Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9172 - loss: 0.0353Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9168 - loss: 0.0352Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9155 - loss: 0.0348 - val_accuracy: 0.9333 - val_loss: 0.0259
# Epoch 5/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9210 - loss: 0.0329Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9204 - loss: 0.0329Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9192 - loss: 0.0331Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9187 - loss: 0.0332Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9170 - loss: 0.0334 - val_accuracy: 0.9333 - val_loss: 0.0254
# Epoch 6/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9205 - loss: 0.0302Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9200 - loss: 0.0308Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9191 - loss: 0.0312Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9187 - loss: 0.0314Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9175 - loss: 0.0318 - val_accuracy: 0.9333 - val_loss: 0.0248
# Epoch 7/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9218 - loss: 0.0310Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9212 - loss: 0.0309Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9201 - loss: 0.0309Processing batch 150
# 197/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9197 - loss: 0.0308Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9184 - loss: 0.0306 - val_accuracy: 0.9333 - val_loss: 0.0242
# Epoch 8/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9228 - loss: 0.0309Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9221 - loss: 0.0305Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9210 - loss: 0.0305Processing batch 150
# 197/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9206 - loss: 0.0303Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9191 - loss: 0.0298 - val_accuracy: 0.9333 - val_loss: 0.0236
# Epoch 9/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9242 - loss: 0.0290Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9232 - loss: 0.0292Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9218 - loss: 0.0293Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9213 - loss: 0.0293Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9195 - loss: 0.0291 - val_accuracy: 0.9333 - val_loss: 0.0233
# Epoch 10/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9221 - loss: 0.0291Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.
50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9242 - loss: 0.0235Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9233 - loss: 0.0234Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9220 - loss: 0.0233Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9216 - loss: 0.0232Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9200 - loss: 0.0230 - val_accuracy: 0.9333 - val_loss: 0.0202
# Epoch 43/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9242 - loss: 0.0236Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9233 - loss: 0.0233Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9221 - loss: 0.0232Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9215 - loss: 0.0231Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9200 - loss: 0.0226 - val_accuracy: 0.9333 - val_loss: 0.0201
# Epoch 44/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9242 - loss: 0.0230Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9232 - loss: 0.0231Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9220 - loss: 0.0232Processing batch 150
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9200 - loss: 0.0228 - val_accuracy: 0.9333 - val_loss: 0.0201
# Epoch 45/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9242 - loss: 0.0237Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9232 - loss: 0.0236Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9221 - loss: 0.0235Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9216 - loss: 0.0234Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9200 - loss: 0.0230 - val_accuracy: 0.9333 - val_loss: 0.0203
# Epoch 46/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9242 - loss: 0.0226Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9233 - loss: 0.0225Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9220 - loss: 0.0226Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9216 - loss: 0.0226Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.9200 - loss: 0.0226 - val_accuracy: 0.9333 - val_loss: 0.0201
# Epoch 47/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9242 - loss: 0.0232Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9232 - loss: 0.0230Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9221 - loss: 0.0230Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9216 - loss: 0.0230Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9200 - loss: 0.0228 - val_accuracy: 0.9333 - val_loss: 0.0201
# Epoch 48/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9242 - loss: 0.0222Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9232 - loss: 0.0223Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9221 - loss: 0.0225Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9216 - loss: 0.0225Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9200 - loss: 0.0226 - val_accuracy: 0.9333 - val_loss: 0.0201
# Epoch 49/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.9242 - loss: 0.0237Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9233 - loss: 0.0234Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9221 - loss: 0.0232Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9216 - loss: 0.0230Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9200 - loss: 0.0225 - val_accuracy: 0.9333 - val_loss: 0.0201
# Epoch 50/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9242 - loss: 0.0229Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9232 - loss: 0.0225Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9221 - loss: 0.0225Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9216 - loss: 0.0224Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.9200 - loss: 0.0221 - val_accuracy: 0.9333 - val_loss: 0.0200
#
# Generating pseudo labels for Chrome dataset...
#
# Retraining model with pseudo-labelled Chrome data...
# Epoch 1/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0192
# Epoch 2/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0192
# Epoch 3/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9378 - loss: 0.0190
# Epoch 4/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9378 - loss: 0.0187
# Epoch 5/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - accuracy: 0.9378 - loss: 0.0185
# Epoch 6/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9378 - loss: 0.0183
# Epoch 7/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9378 - loss: 0.0183
# Epoch 8/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9378 - loss: 0.0183
# Epoch 9/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 15s 22ms/step - accuracy: 0.9378 - loss: 0.0181
# Epoch 10/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.9378 - loss: 0.0177
# Epoch 11/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9378 - loss: 0.0175
# Epoch 12/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9378 - loss: 0.0174
# Epoch 13/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0175
# Epoch 14/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0173
# Epoch 15/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0171
# Epoch 16/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0173
# Epoch 17/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0171
# Epoch 18/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0171
# Epoch 19/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0168
# Epoch 20/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0169
# Epoch 21/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0166
# Epoch 22/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0167
# Epoch 23/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0165
# Epoch 24/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0165
# Epoch 25/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0163
# Epoch 26/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0163
# Epoch 27/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.9378 - loss: 0.0162
# Epoch 28/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9378 - loss: 0.0161
# Epoch 29/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.9378 - loss: 0.0159
# Epoch 30/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 15s 21ms/step - accuracy: 0.9378 - loss: 0.0159
#
# Training XGBoost model...
# Predicting Chrome dataset...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:  0.745
# Precision: 0.269
# Recall:    0.217
# F1-score:  0.240
# AUC:       0.541
# G-mean:    0.466
# PF value:  0.135
#
# Confusion Matrix:
# TN: 3124
# FP: 487
# FN: 646
# TP: 179
