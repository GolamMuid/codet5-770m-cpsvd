# %%
"""
Cross-Project Vulnerability Detection (Class Weighting Version)
---------------------------------------------------------------
Train on Debian → Test on Chrome
Handles class imbalance using algorithm-level class weighting
"""

# =========================================================
# Imports
# =========================================================

import os
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    recall_score,
    precision_score,
    roc_auc_score,
    f1_score,
    confusion_matrix
)
from sklearn.utils.class_weight import compute_class_weight

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import Callback

warnings.filterwarnings("ignore")

# =========================================================
# TensorFlow Configuration
# =========================================================

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

tf.config.run_functions_eagerly(True)

tf.config.threading.set_inter_op_parallelism_threads(0)
tf.config.threading.set_intra_op_parallelism_threads(0)

os.environ["OMP_NUM_THREADS"] = "8"

# =========================================================
# Progress Logger
# =========================================================

class BatchLogger(Callback):

    def on_train_batch_begin(self, batch, logs=None):
        if batch % 50 == 0:
            print(f"Processing batch {batch}")

# =========================================================
# Reproducibility
# =========================================================

seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

os.environ["PYTHONHASHSEED"] = str(seed)

# =========================================================
# Original Configuration
# =========================================================

EPOCHS_INITIAL = 50
EPOCHS_RETRAIN = 30

BATCH_SIZE_INITIAL = 64
BATCH_SIZE_RETRAIN = 32

LEARNING_RATE = 1e-5
NUM_ITERATIONS = 3

# =========================================================
# Neural Network
# =========================================================

def create_neural_network(input_dim: int):

    model = Sequential([
        Dense(256, activation="relu", input_dim=input_dim),
        Dropout(0.2),

        Dense(128, activation="relu"),
        Dropout(0.2),

        Dense(64, activation="relu"),
        Dropout(0.2),

        Dense(32, activation="relu"),
        Dropout(0.2),

        Dense(16, activation="relu"),

        Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================

def semi_supervised_transfer_learning(
        x_train,
        y_train,
        x_test,
        class_weight_dict):

    model = create_neural_network(x_train.shape[1])

    print("\nTraining Neural Network on Debian (Class Weighted)...")

    model.fit(
        x_train,
        y_train,
        epochs=EPOCHS_INITIAL,
        batch_size=BATCH_SIZE_INITIAL,
        validation_split=0.2,
        class_weight=class_weight_dict,
        callbacks=[BatchLogger()],
        verbose=1
    )

    print("\nGenerating pseudo labels for Chrome dataset...")

    y_pred = model.predict(x_test, verbose=0)

    y_pred_binary = (y_pred > 0.5).astype(int).flatten()

    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))

    print("\nRetraining model with pseudo-labelled Chrome data...")

    model.fit(
        x_train_aug,
        y_train_aug,
        epochs=EPOCHS_RETRAIN,
        batch_size=BATCH_SIZE_RETRAIN,
        class_weight=class_weight_dict,
        verbose=1
    )

    return model, y_pred.flatten()


# =========================================================
# XGBoost
# =========================================================

def train_base_model_xgb(x_train, y_train):

    # Compute scale_pos_weight for XGBoost
    neg = np.sum(y_train == 0)
    pos = np.sum(y_train == 1)
    scale_pos_weight = neg / pos

    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        use_label_encoder=False,
        eval_metric="logloss",
        scale_pos_weight=scale_pos_weight
    )

    model.fit(x_train, y_train)

    return model


# =========================================================
# Main
# =========================================================

def main():

    print("\n=== Training on Debian → Testing on Chrome (Class Weighting) ===")

    # -----------------------------------------------------
    # Load Embeddings
    # -----------------------------------------------------

    deb_emb = np.load("../dataset/debian_embeddings.npy")
    deb_lbl = np.load("../dataset/debian_labels.npy")

    chr_emb = np.load("../dataset/chrome_embeddings.npy")
    chr_lbl = np.load("../dataset/chrome_labels.npy")

    deb_emb = deb_emb.astype(np.float32)
    chr_emb = chr_emb.astype(np.float32)

    deb_lbl = deb_lbl.astype(np.float32)
    chr_lbl = chr_lbl.astype(np.float32)

    print("Debian dataset shape:", deb_emb.shape)
    print("Chrome dataset shape:", chr_emb.shape)

    # -----------------------------------------------------
    # Normalize
    # -----------------------------------------------------

    scaler = StandardScaler()

    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    # -----------------------------------------------------
    # Compute Class Weights
    # -----------------------------------------------------

    classes = np.unique(deb_lbl)

    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=classes,
        y=deb_lbl
    )

    class_weight_dict = dict(zip(classes, class_weights))

    print("Class Weights:", class_weight_dict)

    # -----------------------------------------------------
    # Ensemble Training
    # -----------------------------------------------------

    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in range(NUM_ITERATIONS):

        print(f"\n=== Ensemble Iteration {i+1}/{NUM_ITERATIONS} ===")

        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb,
            deb_lbl,
            chr_emb,
            class_weight_dict
        )

        print("\nTraining XGBoost model...")

        model_xgb = train_base_model_xgb(
            deb_emb,
            deb_lbl
        )

        print("Predicting Chrome dataset...")

        model_xgb_pred = model_xgb.predict(chr_emb)

        ensemble_predictions += model_xgb_pred

    # -----------------------------------------------------
    # Average Predictions
    # -----------------------------------------------------

    ensemble_avg = ensemble_predictions / NUM_ITERATIONS

    y_pred_final = (ensemble_avg > 0.5).astype(int)

    # -----------------------------------------------------
    # Metrics
    # -----------------------------------------------------

    accuracy = accuracy_score(chr_lbl, y_pred_final)
    recall = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc = roc_auc_score(chr_lbl, ensemble_avg)
    f1 = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()

    g_mean = np.sqrt(tp / (tp + fn))
    pf = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")

    print(f"Accuracy:  {accuracy:.3f}")
    print(f"Precision: {precision:.3f}")
    print(f"Recall:    {recall:.3f}")
    print(f"F1-score:  {f1:.3f}")
    print(f"AUC:       {auc:.3f}")
    print(f"G-mean:    {g_mean:.3f}")
    print(f"PF value:  {pf:.3f}")

    print("\nConfusion Matrix:")
    print(f"TN: {tn}")
    print(f"FP: {fp}")
    print(f"FN: {fn}")
    print(f"TP: {tp}")

    # -----------------------------------------------------
    # Plot Confusion Matrix
    # -----------------------------------------------------

    cm = confusion_matrix(chr_lbl, y_pred_final)

    plt.figure(figsize=(6, 5))

    plt.imshow(cm, interpolation="nearest")
    plt.title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar()

    tick_marks = np.arange(2)

    plt.xticks(tick_marks, ["Non-Vulnerable", "Vulnerable"])
    plt.yticks(tick_marks, ["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            plt.text(j, i, cm[i, j], ha="center", va="center")

    plt.ylabel("Actual Label")
    plt.xlabel("Predicted Label")

    plt.tight_layout()
    plt.show()


# =========================================================

if __name__ == "__main__":
    main()
# Out:
# === Training on Debian → Testing on Chrome (Class Weighting) ===
# Debian dataset shape: (18298, 1024)
# Chrome dataset shape: (4436, 1024)
# Class Weights: {np.float32(0.0): np.float64(0.5419060593496416), np.float32(1.0): np.float64(6.465724381625441)}
#
# === Ensemble Iteration 1/3 ===
#
# Training Neural Network on Debian (Class Weighted)...
# Epoch 1/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5421 - loss: 0.6723Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5357 - loss: 0.6826Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5369 - loss: 0.6873Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5397 - loss: 0.6882Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5566 - loss: 0.6863 - val_accuracy: 0.6290 - val_loss: 0.6464
# Epoch 2/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5800 - loss: 0.6541Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.5847 - loss: 0.6579Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.5869 - loss: 0.6608Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5890 - loss: 0.6605Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6007 - loss: 0.6570 - val_accuracy: 0.6311 - val_loss: 0.6394
# Epoch 3/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6191 - loss: 0.6423Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6179 - loss: 0.6441Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6164 - loss: 0.6471Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6164 - loss: 0.6473Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6190 - loss: 0.6445 - val_accuracy: 0.6331 - val_loss: 0.6229
# Epoch 4/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6218 - loss: 0.6590Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6282 - loss: 0.6500Processing batch 100
# 147/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6294 - loss: 0.6471Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6302 - loss: 0.6447Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6338 - loss: 0.6366 - val_accuracy: 0.6388 - val_loss: 0.6228
# Epoch 5/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6398 - loss: 0.6206Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6409 - loss: 0.6201Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6388 - loss: 0.6233Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6380 - loss: 0.6242Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6362 - loss: 0.6295 - val_accuracy: 0.6418 - val_loss: 0.6172
# Epoch 6/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6374 - loss: 0.6249Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6367 - loss: 0.6248Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6369 - loss: 0.6267Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6376 - loss: 0.6267Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6413 - loss: 0.6255 - val_accuracy: 0.6467 - val_loss: 0.6044
# Epoch 7/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6538 - loss: 0.6233Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6545 - loss: 0.6236Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6534 - loss: 0.6241Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6523 - loss: 0.6235Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6496 - loss: 0.6200 - val_accuracy: 0.6481 - val_loss: 0.5980
# Epoch 8/50
# Processing batch 0
#  47/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6434 - loss: 0.6453Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6469 - loss: 0.6299Processing batch 100
# 147/229 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.6468 - loss: 0.6268Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6475 - loss: 0.6228Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6498 - loss: 0.6114 - val_accuracy: 0.6514 - val_loss: 0.5931
# Epoch 9/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6348 - loss: 0.6232Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6417 - loss: 0.6178Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6436 - loss: 0.6183Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6443 - loss: 0.6174Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6474 - loss: 0.6122 - val_accuracy: 0.6530 - val_loss: 0.5865
# Epoch 10/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6601 - loss: 0.6259Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6589 - loss: 0.6219Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6576 - loss: 0.6201Processing batch 150
# 197/229 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6566 - loss: 0.6182Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6517 - loss: 0.6109 - val_accuracy: 0.6500 - val_loss: 0.5963
# Epoch 11/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6453 - loss: 0.6092Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.6502 - loss: 0.6091Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6503 - loss: 0.6091Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6502 - loss: 0.6084Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6499 - loss: 0.6064 - val_accuracy: 0.6530 - val_loss: 0.5804
# Epoch 12/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6594 - loss: 0.6170Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6600 - loss: 0.6138Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6589 - loss: 0.6135Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6580 - loss: 0.6120Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6545 - loss: 0.6059 - val_accuracy: 0.6527 - val_loss: 0.5845
# Epoch 13/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6564 - loss: 0.6202Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6588 - loss: 0.6119Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6580 - loss: 0.6090Processing batch 150
# 197/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6575 - loss: 0.6058Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6540 - loss: 0.5934 - val_accuracy: 0.6566 - val_loss: 0.5789
# Epoch 14/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6664 - loss: 0.5958Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6651 - loss: 0.5986Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6638 - loss: 0.6001Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6626 - loss: 0.5992Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6589 - loss: 0.5945 - val_accuracy: 0.6587 - val_loss: 0.5831
# Epoch 15/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6573 - loss: 0.6049Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6597 - loss: 0.5997Processing batch 100
# 147/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6593 - loss: 0.5996Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6583 - loss: 0.5979Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6545 - loss: 0.5926 - val_accuracy: 0.6566 - val_loss: 0.5783
# Epoch 16/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6372 - loss: 0.5962Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6447 - loss: 0.5926Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6467 - loss: 0.5911Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6481 - loss: 0.5895Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6537 - loss: 0.5854 - val_accuracy: 0.6604 - val_loss: 0.5741
# Epoch 17/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6519 - loss: 0.5932Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6525 - loss: 0.5914Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6518 - loss: 0.5918Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6522 - loss: 0.5908Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6554 - loss: 0.5849 - val_accuracy: 0.6658 - val_loss: 0.5706
# Epoch 18/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6679 - loss: 0.5963Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6698 - loss: 0.5916Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6693 - loss: 0.5908Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6685 - loss: 0.5898Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6657 - loss: 0.5869 - val_accuracy: 0.6667 - val_loss: 0.5739
# Epoch 19/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6660 - loss: 0.5794Processing batch 50
#  97/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6655 - loss: 0.5842Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6654 - loss: 0.5857Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6652 - loss: 0.5853Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6640 - loss: 0.5842 - val_accuracy: 0.6675 - val_loss: 0.5769
# Epoch 20/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6760 - loss: 0.5900Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6738 - loss: 0.5887Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6725 - loss: 0.5877Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6709 - loss: 0.5864Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6667 - loss: 0.5840 - val_accuracy: 0.6776 - val_loss: 0.5737
# Epoch 21/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6573 - loss: 0.5998Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6616 - loss: 0.5934Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6620 - loss: 0.5903Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6620 - loss: 0.5873Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6625 - loss: 0.5765 - val_accuracy: 0.6803 - val_loss: 0.5674
# Epoch 22/50
# Processing batch 0
#  47/229 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6760 - loss: 0.5702Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6762 - loss: 0.5765Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6754 - loss: 0.5778Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6743 - loss: 0.5780Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - accuracy: 0.6708 - loss: 0.5784 - val_accuracy: 0.6828 - val_loss: 0.5640
# Epoch 23/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6790 - loss: 0.5710Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6796 - loss: 0.5719Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6769 - loss: 0.5741Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6748 - loss: 0.5738Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6689 - loss: 0.5716 - val_accuracy: 0.6828 - val_loss: 0.5641
# Epoch 24/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6722 - loss: 0.5651Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6735 - loss: 0.5696Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6726 - loss: 0.5730Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6722 - loss: 0.5734Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6713 - loss: 0.5707 - val_accuracy: 0.6773 - val_loss: 0.5700
# Epoch 25/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6618 - loss: 0.5900Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6672 - loss: 0.5816Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6685 - loss: 0.5792Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6698 - loss: 0.5765Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6737 - loss: 0.5695 - val_accuracy: 0.6885 - val_loss: 0.5635
# Epoch 26/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6796 - loss: 0.5702Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6792 - loss: 0.5732Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6781 - loss: 0.5726Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6763 - loss: 0.5713Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6715 - loss: 0.5654 - val_accuracy: 0.6888 - val_loss: 0.5580
# Epoch 27/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6710 - loss: 0.5825Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6755 - loss: 0.5757Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6758 - loss: 0.5737Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6750 - loss: 0.5711Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6728 - loss: 0.5635 - val_accuracy: 0.6858 - val_loss: 0.5629
# Epoch 28/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6742 - loss: 0.5867Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6789 - loss: 0.5773Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6786 - loss: 0.5735Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6775 - loss: 0.5707Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6774 - loss: 0.5617 - val_accuracy: 0.7096 - val_loss: 0.5490
# Epoch 29/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6853 - loss: 0.5669Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6864 - loss: 0.5662Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6864 - loss: 0.5650Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6852 - loss: 0.5639Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6794 - loss: 0.5606 - val_accuracy: 0.6918 - val_loss: 0.5658
# Epoch 30/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6774 - loss: 0.5778Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6805 - loss: 0.5696Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6810 - loss: 0.5662Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6807 - loss: 0.5633Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6788 - loss: 0.5541 - val_accuracy: 0.6978 - val_loss: 0.5581
# Epoch 31/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6879 - loss: 0.5665Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6872 - loss: 0.5580Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6858 - loss: 0.5565Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6852 - loss: 0.5551Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6836 - loss: 0.5467 - val_accuracy: 0.7071 - val_loss: 0.5559
# Epoch 32/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7031 - loss: 0.5369Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7035 - loss: 0.5401Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7013 - loss: 0.5438Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6994 - loss: 0.5443Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6910 - loss: 0.5476 - val_accuracy: 0.7175 - val_loss: 0.5467
# Epoch 33/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6995 - loss: 0.5553Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6994 - loss: 0.5534Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6980 - loss: 0.5537Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6963 - loss: 0.5536Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6884 - loss: 0.5529 - val_accuracy: 0.7019 - val_loss: 0.5599
# Epoch 34/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6940 - loss: 0.5646Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6929 - loss: 0.5588Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6924 - loss: 0.5557Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6913 - loss: 0.5538Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6875 - loss: 0.5469 - val_accuracy: 0.7060 - val_loss: 0.5590
# Epoch 35/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.6899 - loss: 0.5644Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6904 - loss: 0.5622Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.6913 - loss: 0.5596Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.6917 - loss: 0.5566Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6928 - loss: 0.5469 - val_accuracy: 0.7221 - val_loss: 0.5465
# Epoch 36/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7108 - loss: 0.5533Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7120 - loss: 0.5485Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7103 - loss: 0.5468Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7094 - loss: 0.5459Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7058 - loss: 0.5422 - val_accuracy: 0.7320 - val_loss: 0.5411
# Epoch 37/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7112 - loss: 0.5795Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7106 - loss: 0.5699Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7084 - loss: 0.5637Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7063 - loss: 0.5598Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.6982 - loss: 0.5478 - val_accuracy: 0.7230 - val_loss: 0.5486
# Epoch 38/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7107 - loss: 0.5588Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7116 - loss: 0.5529Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7109 - loss: 0.5494Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7100 - loss: 0.5467Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7060 - loss: 0.5369 - val_accuracy: 0.7347 - val_loss: 0.5314
# Epoch 39/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7179 - loss: 0.5357Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7174 - loss: 0.5444Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7146 - loss: 0.5465Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7123 - loss: 0.5463Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7041 - loss: 0.5425 - val_accuracy: 0.7311 - val_loss: 0.5425
# Epoch 40/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7170 - loss: 0.5356Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7162 - loss: 0.5367Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7143 - loss: 0.5378Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7121 - loss: 0.5384Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.7077 - loss: 0.5391 - val_accuracy: 0.7284 - val_loss: 0.5430
# Epoch 41/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7248 - loss: 0.5419Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7212 - loss: 0.5421Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7183 - loss: 0.5422Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7162 - loss: 0.5410Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7112 - loss: 0.5369 - val_accuracy: 0.7322 - val_loss: 0.5466
# Epoch 42/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7151 - loss: 0.5514Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7141 - loss: 0.5483Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7129 - loss: 0.5458Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7118 - loss: 0.5434Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7094 - loss: 0.5320 - val_accuracy: 0.7314 - val_loss: 0.5447
# Epoch 43/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7283 - loss: 0.5548Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7261 - loss: 0.5497Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7241 - loss: 0.5468Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7226 - loss: 0.5439Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7168 - loss: 0.5326 - val_accuracy: 0.7383 - val_loss: 0.5357
# Epoch 44/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7206 - loss: 0.5355Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.7221 - loss: 0.5345Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7219 - loss: 0.5340Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7210 - loss: 0.5326Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7173 - loss: 0.5270 - val_accuracy: 0.7287 - val_loss: 0.5436
# Epoch 45/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7238 - loss: 0.5620Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7244 - loss: 0.5470Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7238 - loss: 0.5411Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7232 - loss: 0.5378Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.7210 - loss: 0.5247 - val_accuracy: 0.7410 - val_loss: 0.5328
# Epoch 46/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7194 - loss: 0.5440Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7214 - loss: 0.5407Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7219 - loss: 0.5384Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7218 - loss: 0.5359Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 19ms/step - accuracy: 0.7209 - loss: 0.5267 - val_accuracy: 0.7454 - val_loss: 0.5383
# Epoch 47/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7489 - loss: 0.5440Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7453 - loss: 0.5369Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7413 - loss: 0.5345Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7379 - loss: 0.5328Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.7260 - loss: 0.5269 - val_accuracy: 0.7418 - val_loss: 0.5326
# Epoch 48/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7266 - loss: 0.5423Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7273 - loss: 0.5351Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7262 - loss: 0.5325Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7257 - loss: 0.5304Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.7255 - loss: 0.5217 - val_accuracy: 0.7443 - val_loss: 0.5259
# Epoch 49/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7271 - loss: 0.5593Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7294 - loss: 0.5458Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7285 - loss: 0.5405Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7272 - loss: 0.5367Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step - accuracy: 0.7235 - loss: 0.5205 - val_accuracy: 0.7432 - val_loss: 0.5250
# Epoch 50/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.7277 - loss: 0.5194Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7313 - loss: 0.5184Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.7319 - loss: 0.5175Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7318 - loss: 0.5165Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.7312 - loss: 0.5116 - val_accuracy: 0.7451 - val_loss: 0.5233
#
# Generating pseudo labels for Chrome dataset...
#
# Retraining model with pseudo-labelled Chrome data...
# Epoch 1/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.6929 - loss: 0.6100
# Epoch 2/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.6931 - loss: 0.5830
# Epoch 3/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.6985 - loss: 0.5690
# Epoch 4/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7028 - loss: 0.5605
# Epoch 5/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.7103 - loss: 0.5501
# Epoch 6/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7180 - loss: 0.5490
# Epoch 7/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7269 - loss: 0.5342
# Epoch 8/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7268 - loss: 0.5288
# Epoch 9/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.7337 - loss: 0.5266
# Epoch 10/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7431 - loss: 0.5125
# Epoch 11/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7403 - loss: 0.5160
# Epoch 12/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7475 - loss: 0.5106
# Epoch 13/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7491 - loss: 0.5020
# Epoch 14/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.7492 - loss: 0.5019
# Epoch 15/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.7532 - loss: 0.5004
# Epoch 16/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7561 - loss: 0.4916
# Epoch 17/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7593 - loss: 0.4896
# Epoch 18/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7610 - loss: 0.4860
# Epoch 19/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7627 - loss: 0.4808
# Epoch 20/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.7623 - loss: 0.4731
# Epoch 21/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.7632 - loss: 0.4765
# Epoch 22/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.7661 - loss: 0.4769
# Epoch 23/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7672 - loss: 0.4662
# Epoch 24/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7695 - loss: 0.4642
# Epoch 25/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7723 - loss: 0.4643
# Epoch 26/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.7757 - loss: 0.4510
# Epoch 27/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7774 - loss: 0.4519
# Epoch 28/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 19ms/step - accuracy: 0.7764 - loss: 0.4491
# Epoch 29/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.7791 - loss: 0.4457
# Epoch 30/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 13s 18ms/step - accuracy: 0.7856 - loss: 0.4448
#
# Training XGBoost model...
# Predicting Chrome dataset...
#
# === Ensemble Iteration 2/3 ===
#
# Training Neural Network on Debian (Class Weighted)...
# Epoch 1/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5720 - loss: 0.6995Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5732 - loss: 0.6997Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5737 - loss: 0.6996Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5748 - loss: 0.6969Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5786 - loss: 0.6878 - val_accuracy: 0.5571 - val_loss: 0.6514
# Epoch 2/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5792 - loss: 0.6520Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5817 - loss: 0.6555Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5816 - loss: 0.6584Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5816 - loss: 0.6588Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5842 - loss: 0.6585 - val_accuracy: 0.5617 - val_loss: 0.6409
# Epoch 3/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5553 - loss: 0.6573Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5655 - loss: 0.6538Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5688 - loss: 0.6551Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5711 - loss: 0.6548Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5790 - loss: 0.6526 - val_accuracy: 0.5648 - val_loss: 0.6534
# Epoch 4/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.5829 - loss: 0.6528Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5855 - loss: 0.6491Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.5857 - loss: 0.6465Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.5865 - loss: 0.6453Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.5897 - loss: 0.6434 - val_accuracy: 0.5768 - val_loss: 0.6481
# Epoch 5/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5717 - loss: 0.6502Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5793 - loss: 0.6411Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5817 - loss: 0.6388Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5839 - loss: 0.6369Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5930 - loss: 0.6312 - val_accuracy: 0.5850 - val_loss: 0.6416
# Epoch 6/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5870 - loss: 0.6404Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5913 - loss: 0.6380Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.5931 - loss: 0.6380Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.5945 - loss: 0.6375Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5993 - loss: 0.6343 - val_accuracy: 0.5883 - val_loss: 0.6367
# Epoch 7/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5928 - loss: 0.6282Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.5983 - loss: 0.6283Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6007 - loss: 0.6292Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6022 - loss: 0.6288Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6075 - loss: 0.6278 - val_accuracy: 0.6005 - val_loss: 0.6291
# Epoch 8/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.5991 - loss: 0.6239Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6053 - loss: 0.6213Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6076 - loss: 0.6205Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6091 - loss: 0.6194Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6149 - loss: 0.6168 - val_accuracy: 0.6077 - val_loss: 0.6235
# Epoch 9/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6287 - loss: 0.6453Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6267 - loss: 0.6350Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6249 - loss: 0.6332Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6241 - loss: 0.6307Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6226 - loss: 0.6250 - val_accuracy: 0.6038 - val_loss: 0.6227
# Epoch 10/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6162 - loss: 0.6046Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6164 - loss: 0.6093Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6158 - loss: 0.6115Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6158 - loss: 0.6116Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6177 - loss: 0.6096 - val_accuracy: 0.6082 - val_loss: 0.6176
# Epoch 11/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6157 - loss: 0.6204Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6182 - loss: 0.6176Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6189 - loss: 0.6172Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6196 - loss: 0.6162Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.6224 - loss: 0.6142 - val_accuracy: 0.6068 - val_loss: 0.6062
# Epoch 12/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6184 - loss: 0.6290Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6203 - loss: 0.6221Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6213 - loss: 0.6196Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6219 - loss: 0.6169Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6252 - loss: 0.6084 - val_accuracy: 0.6077 - val_loss: 0.6070
# Epoch 13/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6273 - loss: 0.6096Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6299 - loss: 0.5991Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6297 - loss: 0.5995Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6299 - loss: 0.5993Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6286 - loss: 0.6008 - val_accuracy: 0.6098 - val_loss: 0.6027
# Epoch 14/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6229 - loss: 0.6156Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6254 - loss: 0.6105Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6264 - loss: 0.6101Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6265 - loss: 0.6087Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6272 - loss: 0.6043 - val_accuracy: 0.6126 - val_loss: 0.5944
# Epoch 15/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6256 - loss: 0.6142Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6282 - loss: 0.6113Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6286 - loss: 0.6097Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6287 - loss: 0.6079Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6308 - loss: 0.5995 - val_accuracy: 0.6128 - val_loss: 0.5916
# Epoch 16/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6433 - loss: 0.6192Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6418 - loss: 0.6161Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6401 - loss: 0.6143Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6389 - loss: 0.6121Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6348 - loss: 0.6024 - val_accuracy: 0.6120 - val_loss: 0.5937
# Epoch 17/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6145 - loss: 0.6004Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6240 - loss: 0.5946Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.6268 - loss: 0.5937Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6283 - loss: 0.5932Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.6327 - loss: 0.5928 - val_accuracy: 0.6148 - val_loss: 0.5828
# Epoch 18/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6357 - loss: 0.5979Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6383 - loss: 0.5923Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6380 - loss: 0.5916Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6380 - loss: 0.5902Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6373 - loss: 0.5846 - val_accuracy: 0.6175 - val_loss: 0.5849
# Epoch 19/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6281 - loss: 0.6091Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6353 - loss: 0.5991Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6368 - loss: 0.5963Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6369 - loss: 0.5937Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6379 - loss: 0.5876 - val_accuracy: 0.6194 - val_loss: 0.5826
# Epoch 20/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6427 - loss: 0.5795Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6458 - loss: 0.5832Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6459 - loss: 0.5846Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6455 - loss: 0.5846Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6448 - loss: 0.5843 - val_accuracy: 0.6208 - val_loss: 0.5836
# Epoch 21/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6370 - loss: 0.5960Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6349 - loss: 0.5934Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6339 - loss: 0.5940Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6340 - loss: 0.5926Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6371 - loss: 0.5885 - val_accuracy: 0.6221 - val_loss: 0.5813
# Epoch 22/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6439 - loss: 0.6003Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6450 - loss: 0.5947Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6440 - loss: 0.5936Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6430 - loss: 0.5917Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6420 - loss: 0.5839 - val_accuracy: 0.6270 - val_loss: 0.5810
# Epoch 23/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6411 - loss: 0.5819Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6428 - loss: 0.5808Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6432 - loss: 0.5811Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6434 - loss: 0.5800Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6450 - loss: 0.5753 - val_accuracy: 0.6317 - val_loss: 0.5743
# Epoch 24/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6462 - loss: 0.5977Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6494 - loss: 0.5896Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6494 - loss: 0.5866Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6497 - loss: 0.5833Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6506 - loss: 0.5741 - val_accuracy: 0.6314 - val_loss: 0.5748
# Epoch 25/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.6512 - loss: 0.5990Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6556 - loss: 0.5900Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6553 - loss: 0.5874Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6541 - loss: 0.5852Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6518 - loss: 0.5755 - val_accuracy: 0.6344 - val_loss: 0.5731
# Epoch 26/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.6579 - loss: 0.6057Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6598 - loss: 0.5951Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.6588 - loss: 0.5900Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.6578 - loss: 0.5863Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6559 - loss: 0.5751 - val_accuracy: 0.6402 - val_loss: 0.5702
# Epoch 27/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6583 - loss: 0.5773Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6598 - loss: 0.5730Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6598 - loss: 0.5725Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6597 - loss: 0.5715Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6607 - loss: 0.5677 - val_accuracy: 0.6426 - val_loss: 0.5675
# Epoch 28/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6678 - loss: 0.5723Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6662 - loss: 0.5757Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6647 - loss: 0.5748Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6640 - loss: 0.5728Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6646 - loss: 0.5649 - val_accuracy: 0.6538 - val_loss: 0.5564
# Epoch 29/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6623 - loss: 0.5730Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6626 - loss: 0.5705Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6627 - loss: 0.5692Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6631 - loss: 0.5668Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6666 - loss: 0.5585 - val_accuracy: 0.6596 - val_loss: 0.5484
# Epoch 30/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6682 - loss: 0.5788Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.6715 - loss: 0.5749Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6713 - loss: 0.5720Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6712 - loss: 0.5689Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6732 - loss: 0.5578 - val_accuracy: 0.6604 - val_loss: 0.5471
# Epoch 31/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.6723 - loss: 0.5850Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6740 - loss: 0.5764Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6754 - loss: 0.5725Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6755 - loss: 0.5705Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6760 - loss: 0.5617 - val_accuracy: 0.6609 - val_loss: 0.5541
# Epoch 32/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6775 - loss: 0.5752Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6753 - loss: 0.5681Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6731 - loss: 0.5662Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6716 - loss: 0.5638Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.6697 - loss: 0.5551 - val_accuracy: 0.6653 - val_loss: 0.5478
# Epoch 33/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6830 - loss: 0.5730Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6809 - loss: 0.5686Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6789 - loss: 0.5662Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6776 - loss: 0.5633Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6736 - loss: 0.5546 - val_accuracy: 0.6697 - val_loss: 0.5441
# Epoch 34/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6846 - loss: 0.5815Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6863 - loss: 0.5745Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6851 - loss: 0.5698Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6843 - loss: 0.5663Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6820 - loss: 0.5547 - val_accuracy: 0.6724 - val_loss: 0.5460
# Epoch 35/50
# Processing batch 0
# ...
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6884 - loss: 0.5737 - val_accuracy: 0.7038 - val_loss: 0.5597
# Epoch 27/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6943 - loss: 0.5790Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6953 - loss: 0.5782Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6947 - loss: 0.5781Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6944 - loss: 0.5767Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6932 - loss: 0.5714 - val_accuracy: 0.7101 - val_loss: 0.5547
# Epoch 28/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7039 - loss: 0.5788Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7035 - loss: 0.5771Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7012 - loss: 0.5768Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6992 - loss: 0.5750Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6939 - loss: 0.5667 - val_accuracy: 0.7115 - val_loss: 0.5582
# Epoch 29/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6937 - loss: 0.5802Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6954 - loss: 0.5790Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.6962 - loss: 0.5771Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6966 - loss: 0.5750Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6978 - loss: 0.5675 - val_accuracy: 0.7112 - val_loss: 0.5607
# Epoch 30/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.6943 - loss: 0.5820Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.6994 - loss: 0.5764Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7001 - loss: 0.5731Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6996 - loss: 0.5709Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6982 - loss: 0.5624 - val_accuracy: 0.7183 - val_loss: 0.5532
# Epoch 31/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7050 - loss: 0.5869Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7031 - loss: 0.5832Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7021 - loss: 0.5805Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7007 - loss: 0.5773Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6954 - loss: 0.5631 - val_accuracy: 0.7178 - val_loss: 0.5518
# Epoch 32/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7087 - loss: 0.5681Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7057 - loss: 0.5651Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7030 - loss: 0.5638Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7015 - loss: 0.5618Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6978 - loss: 0.5578 - val_accuracy: 0.7197 - val_loss: 0.5520
# Epoch 33/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.6991 - loss: 0.5740Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7018 - loss: 0.5729Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7020 - loss: 0.5708Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7010 - loss: 0.5680Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6987 - loss: 0.5580 - val_accuracy: 0.7186 - val_loss: 0.5548
# Epoch 34/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7048 - loss: 0.5684Processing batch 50
#  98/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7065 - loss: 0.5632Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7054 - loss: 0.5620Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7047 - loss: 0.5602Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7049 - loss: 0.5526 - val_accuracy: 0.7265 - val_loss: 0.5450
# Epoch 35/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7009 - loss: 0.5726Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7071 - loss: 0.5694Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7071 - loss: 0.5677Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7061 - loss: 0.5649Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7017 - loss: 0.5550 - val_accuracy: 0.7254 - val_loss: 0.5469
# Epoch 36/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7100 - loss: 0.5620Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7088 - loss: 0.5610Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7073 - loss: 0.5607Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7059 - loss: 0.5586Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7017 - loss: 0.5523 - val_accuracy: 0.7290 - val_loss: 0.5484
# Epoch 37/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7143 - loss: 0.5556Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7137 - loss: 0.5560Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7122 - loss: 0.5554Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7116 - loss: 0.5535Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7112 - loss: 0.5466 - val_accuracy: 0.7369 - val_loss: 0.5437
# Epoch 38/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.7275 - loss: 0.5596Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7251 - loss: 0.5562Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7229 - loss: 0.5548Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7214 - loss: 0.5533Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7169 - loss: 0.5475 - val_accuracy: 0.7281 - val_loss: 0.5521
# Epoch 39/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7187 - loss: 0.5792Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7158 - loss: 0.5679Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7144 - loss: 0.5636Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7133 - loss: 0.5595Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7114 - loss: 0.5425 - val_accuracy: 0.7415 - val_loss: 0.5356
# Epoch 40/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7166 - loss: 0.5602Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7173 - loss: 0.5579Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7180 - loss: 0.5549Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7180 - loss: 0.5513Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7177 - loss: 0.5410 - val_accuracy: 0.7462 - val_loss: 0.5283
# Epoch 41/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7221 - loss: 0.5668Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7243 - loss: 0.5592Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7248 - loss: 0.5558Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7243 - loss: 0.5523Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7221 - loss: 0.5426 - val_accuracy: 0.7413 - val_loss: 0.5328
# Epoch 42/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7152 - loss: 0.5625Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7173 - loss: 0.5550Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7172 - loss: 0.5511Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7165 - loss: 0.5477Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7168 - loss: 0.5363 - val_accuracy: 0.7396 - val_loss: 0.5376
# Epoch 43/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7191 - loss: 0.5578Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7161 - loss: 0.5542Processing batch 100
# 149/229 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7158 - loss: 0.5528Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7158 - loss: 0.5501Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7190 - loss: 0.5367 - val_accuracy: 0.7527 - val_loss: 0.5225
# Epoch 44/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7347 - loss: 0.5596Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7328 - loss: 0.5547Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7308 - loss: 0.5516Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7295 - loss: 0.5480Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7269 - loss: 0.5354 - val_accuracy: 0.7544 - val_loss: 0.5261
# Epoch 45/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7398 - loss: 0.5449Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7342 - loss: 0.5460Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7308 - loss: 0.5452Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7288 - loss: 0.5437Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7232 - loss: 0.5376 - val_accuracy: 0.7500 - val_loss: 0.5319
# Epoch 46/50
# Processing batch 0
#  50/229 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.7373 - loss: 0.5411Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.7370 - loss: 0.5363Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7361 - loss: 0.5355Processing batch 150
# 200/229 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7347 - loss: 0.5341Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7306 - loss: 0.5278 - val_accuracy: 0.7497 - val_loss: 0.5243
# Epoch 47/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7414 - loss: 0.5492Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7399 - loss: 0.5439Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7389 - loss: 0.5418Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7374 - loss: 0.5398Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7304 - loss: 0.5321 - val_accuracy: 0.7445 - val_loss: 0.5329
# Epoch 48/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7406 - loss: 0.5241Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.7370 - loss: 0.5283Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7350 - loss: 0.5288Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7335 - loss: 0.5286Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7297 - loss: 0.5277 - val_accuracy: 0.7505 - val_loss: 0.5235
# Epoch 49/50
# Processing batch 0
#  49/229 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7236 - loss: 0.5417Processing batch 50
# 100/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7262 - loss: 0.5355Processing batch 100
# 148/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7256 - loss: 0.5333Processing batch 150
# 199/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7253 - loss: 0.5317Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7265 - loss: 0.5239 - val_accuracy: 0.7462 - val_loss: 0.5264
# Epoch 50/50
# Processing batch 0
#  48/229 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.7482 - loss: 0.5375Processing batch 50
#  99/229 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.7444 - loss: 0.5334Processing batch 100
# 150/229 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7419 - loss: 0.5306Processing batch 150
# 198/229 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7398 - loss: 0.5282Processing batch 200
# 229/229 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7335 - loss: 0.5192 - val_accuracy: 0.7445 - val_loss: 0.5305
#
# Generating pseudo labels for Chrome dataset...
#
# Retraining model with pseudo-labelled Chrome data...
# Epoch 1/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7023 - loss: 0.5929
# Epoch 2/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7014 - loss: 0.5767
# Epoch 3/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7004 - loss: 0.5591
# Epoch 4/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7082 - loss: 0.5518
# Epoch 5/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7193 - loss: 0.5410
# Epoch 6/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7240 - loss: 0.5327
# Epoch 7/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7254 - loss: 0.5336
# Epoch 8/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7287 - loss: 0.5260
# Epoch 9/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7333 - loss: 0.5199
# Epoch 10/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7382 - loss: 0.5116
# Epoch 11/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7462 - loss: 0.5066
# Epoch 12/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7487 - loss: 0.5031
# Epoch 13/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7494 - loss: 0.5013
# Epoch 14/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7508 - loss: 0.4953
# Epoch 15/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7547 - loss: 0.4863
# Epoch 16/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7553 - loss: 0.4929
# Epoch 17/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7588 - loss: 0.4870
# Epoch 18/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7591 - loss: 0.4811
# Epoch 19/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7613 - loss: 0.4769
# Epoch 20/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7637 - loss: 0.4728
# Epoch 21/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7685 - loss: 0.4640
# Epoch 22/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7684 - loss: 0.4687
# Epoch 23/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 15s 20ms/step - accuracy: 0.7688 - loss: 0.4597
# Epoch 24/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7692 - loss: 0.4625
# Epoch 25/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7708 - loss: 0.4584
# Epoch 26/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7747 - loss: 0.4489
# Epoch 27/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7758 - loss: 0.4494
# Epoch 28/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7771 - loss: 0.4476
# Epoch 29/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7766 - loss: 0.4473
# Epoch 30/30
# 711/711 ━━━━━━━━━━━━━━━━━━━━ 14s 20ms/step - accuracy: 0.7797 - loss: 0.4391
#
# Training XGBoost model...
# Predicting Chrome dataset...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:  0.745
# Precision: 0.269
# Recall:    0.217
# F1-score:  0.240
# AUC:       0.541
# G-mean:    0.466
# PF value:  0.135
#
# Confusion Matrix:
# TN: 3124
# FP: 487
# FN: 646
# TP: 179
