# %%
"""
Cross-Project Vulnerability Detection (SMOTE Version)
-----------------------------------------------------
Train on Debian → Test on Chrome
Handles class imbalance using SMOTE
"""

# =========================================================
# Imports
# =========================================================

import os
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    recall_score,
    precision_score,
    roc_auc_score,
    f1_score,
    confusion_matrix
)

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import Callback

from imblearn.over_sampling import SMOTE

warnings.filterwarnings("ignore")

# =========================================================
# TensorFlow Configuration
# =========================================================

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

tf.config.run_functions_eagerly(True)

tf.config.threading.set_inter_op_parallelism_threads(0)
tf.config.threading.set_intra_op_parallelism_threads(0)

os.environ["OMP_NUM_THREADS"] = "8"

# =========================================================
# Progress Logger
# =========================================================

class BatchLogger(Callback):

    def on_train_batch_begin(self, batch, logs=None):
        if batch % 50 == 0:
            print(f"Processing batch {batch}")

# =========================================================
# Reproducibility
# =========================================================

seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

os.environ["PYTHONHASHSEED"] = str(seed)

# =========================================================
# Original Configuration
# =========================================================

EPOCHS_INITIAL = 50
EPOCHS_RETRAIN = 30

BATCH_SIZE_INITIAL = 64
BATCH_SIZE_RETRAIN = 32

LEARNING_RATE = 1e-5
NUM_ITERATIONS = 3

# =========================================================
# Neural Network
# =========================================================

def create_neural_network(input_dim: int):

    model = Sequential([
        Dense(256, activation="relu", input_dim=input_dim),
        Dropout(0.2),

        Dense(128, activation="relu"),
        Dropout(0.2),

        Dense(64, activation="relu"),
        Dropout(0.2),

        Dense(32, activation="relu"),
        Dropout(0.2),

        Dense(16, activation="relu"),

        Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model


# =========================================================
# Semi-supervised Transfer Learning
# =========================================================

def semi_supervised_transfer_learning(
        x_train,
        y_train,
        x_test):

    model = create_neural_network(x_train.shape[1])

    print("\nTraining Neural Network on Debian (SMOTE balanced)...")

    model.fit(
        x_train,
        y_train,
        epochs=EPOCHS_INITIAL,
        batch_size=BATCH_SIZE_INITIAL,
        validation_split=0.2,
        callbacks=[BatchLogger()],
        verbose=1
    )

    print("\nGenerating pseudo labels for Chrome dataset...")

    y_pred = model.predict(x_test, verbose=0)

    y_pred_binary = (y_pred > 0.5).astype(int).flatten()

    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))

    print("\nRetraining model with pseudo-labelled Chrome data...")

    model.fit(
        x_train_aug,
        y_train_aug,
        epochs=EPOCHS_RETRAIN,
        batch_size=BATCH_SIZE_RETRAIN,
        verbose=1
    )

    return model, y_pred.flatten()


# =========================================================
# XGBoost
# =========================================================

def train_base_model_xgb(x_train, y_train):

    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        use_label_encoder=False,
        eval_metric="logloss"
    )

    model.fit(x_train, y_train)

    return model


# =========================================================
# Main
# =========================================================

def main():

    print("\n=== Training on Debian → Testing on Chrome (SMOTE) ===")

    # -----------------------------------------------------
    # Load Embeddings
    # -----------------------------------------------------

    deb_emb = np.load("dataset/debian_embeddings.npy")
    deb_lbl = np.load("dataset/debian_labels.npy")

    chr_emb = np.load("dataset/chrome_embeddings.npy")
    chr_lbl = np.load("dataset/chrome_labels.npy")

    deb_emb = deb_emb.astype(np.float32)
    chr_emb = chr_emb.astype(np.float32)

    deb_lbl = deb_lbl.astype(np.float32)
    chr_lbl = chr_lbl.astype(np.float32)

    print("Debian dataset shape:", deb_emb.shape)
    print("Chrome dataset shape:", chr_emb.shape)

    # -----------------------------------------------------
    # Normalize
    # -----------------------------------------------------

    scaler = StandardScaler()

    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    # -----------------------------------------------------
    # Apply SMOTE
    # -----------------------------------------------------

    print("\nApplying SMOTE to balance Debian dataset...")

    smote = SMOTE(random_state=seed)

    deb_emb_smote, deb_lbl_smote = smote.fit_resample(
        deb_emb,
        deb_lbl
    )

    print("After SMOTE:", deb_emb_smote.shape)

    # -----------------------------------------------------
    # Ensemble Training
    # -----------------------------------------------------

    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in range(NUM_ITERATIONS):

        print(f"\n=== Ensemble Iteration {i+1}/{NUM_ITERATIONS} ===")

        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_smote,
            deb_lbl_smote,
            chr_emb
        )

        print("\nTraining XGBoost model...")

        model_xgb = train_base_model_xgb(
            deb_emb_smote,
            deb_lbl_smote
        )

        print("Predicting Chrome dataset...")

        model_xgb_pred = model_xgb.predict(chr_emb)

        ensemble_predictions += model_xgb_pred

    # -----------------------------------------------------
    # Average Predictions
    # -----------------------------------------------------

    ensemble_avg = ensemble_predictions / NUM_ITERATIONS

    y_pred_final = (ensemble_avg > 0.5).astype(int)

    # -----------------------------------------------------
    # Metrics
    # -----------------------------------------------------

    accuracy = accuracy_score(chr_lbl, y_pred_final)
    recall = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc = roc_auc_score(chr_lbl, ensemble_avg)
    f1 = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()

    g_mean = np.sqrt(tp / (tp + fn))
    pf = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")

    print(f"Accuracy:  {accuracy:.3f}")
    print(f"Precision: {precision:.3f}")
    print(f"Recall:    {recall:.3f}")
    print(f"F1-score:  {f1:.3f}")
    print(f"AUC:       {auc:.3f}")
    print(f"G-mean:    {g_mean:.3f}")
    print(f"PF value:  {pf:.3f}")

    print("\nConfusion Matrix:")
    print(f"TN: {tn}")
    print(f"FP: {fp}")
    print(f"FN: {fn}")
    print(f"TP: {tp}")

    # -----------------------------------------------------
    # Plot Confusion Matrix
    # -----------------------------------------------------

    cm = confusion_matrix(chr_lbl, y_pred_final)

    plt.figure(figsize=(6, 5))

    plt.imshow(cm, interpolation="nearest")
    plt.title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar()

    tick_marks = np.arange(2)

    plt.xticks(tick_marks, ["Non-Vulnerable", "Vulnerable"])
    plt.yticks(tick_marks, ["Non-Vulnerable", "Vulnerable"])

    for i in range(2):
        for j in range(2):
            plt.text(j, i, cm[i, j], ha="center", va="center")

    plt.ylabel("Actual Label")
    plt.xlabel("Predicted Label")

    plt.tight_layout()
    plt.show()


# =========================================================

if __name__ == "__main__":
    main()
# Out:
# === Training on Debian → Testing on Chrome (SMOTE) ===
# Debian dataset shape: (18298, 1024)
# Chrome dataset shape: (4436, 1024)
#
# Applying SMOTE to balance Debian dataset...
# After SMOTE: (33766, 1024)
#
# === Ensemble Iteration 1/3 ===
#
# Training Neural Network on Debian (SMOTE balanced)...
# Epoch 1/50
# Processing batch 0
#  50/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.5422 - loss: 0.6918Processing batch 50
#  99/423 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.5546 - loss: 0.6881Processing batch 100
# 149/423 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5634 - loss: 0.6843Processing batch 150
# 200/423 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.5707 - loss: 0.6803Processing batch 200
# 250/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5772 - loss: 0.6764Processing batch 250
# 297/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5824 - loss: 0.6728Processing batch 300
# 349/423 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5879 - loss: 0.6689Processing batch 350
# 398/423 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5925 - loss: 0.6654Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6312 - loss: 0.6358 - val_accuracy: 0.6574 - val_loss: 0.7732
# Epoch 2/50
# Processing batch 0
#  47/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6578 - loss: 0.6074Processing batch 50
#  98/423 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6648 - loss: 0.6035Processing batch 100
# 150/423 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6668 - loss: 0.6027Processing batch 150
# 199/423 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6683 - loss: 0.6018Processing batch 200
# 249/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6698 - loss: 0.6006Processing batch 250
# 298/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6711 - loss: 0.5995Processing batch 300
# 349/423 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6724 - loss: 0.5984Processing batch 350
# 400/423 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6736 - loss: 0.5974Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6826 - loss: 0.5889 - val_accuracy: 0.6683 - val_loss: 0.7341
# Epoch 3/50
# Processing batch 0
#  48/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6637 - loss: 0.5989Processing batch 50
#  99/423 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6728 - loss: 0.5937Processing batch 100
# 149/423 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6755 - loss: 0.5918Processing batch 150
# 200/423 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6773 - loss: 0.5905Processing batch 200
# 250/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6793 - loss: 0.5892Processing batch 250
# 299/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.6812 - loss: 0.5878Processing batch 300
# 349/423 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.6830 - loss: 0.5864Processing batch 350
# 400/423 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6846 - loss: 0.5851Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6972 - loss: 0.5737 - val_accuracy: 0.6569 - val_loss: 0.7022
# Epoch 4/50
# Processing batch 0
#  50/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.6881 - loss: 0.5852Processing batch 50
#  98/423 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.6951 - loss: 0.5777Processing batch 100
# 150/423 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.6980 - loss: 0.5746Processing batch 150
# 199/423 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.6999 - loss: 0.5729Processing batch 200
# 248/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7015 - loss: 0.5715Processing batch 250
# 300/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7029 - loss: 0.5700Processing batch 300
# 349/423 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7041 - loss: 0.5687Processing batch 350
# 399/423 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7051 - loss: 0.5675Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7139 - loss: 0.5574 - val_accuracy: 0.6319 - val_loss: 0.6855
# Epoch 5/50
# Processing batch 0
#  50/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7084 - loss: 0.5631Processing batch 50
#  97/423 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7108 - loss: 0.5610Processing batch 100
# 150/423 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7119 - loss: 0.5590Processing batch 150
# 200/423 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7126 - loss: 0.5575Processing batch 200
# 249/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7133 - loss: 0.5563Processing batch 250
# 300/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7141 - loss: 0.5551Processing batch 300
# 349/423 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7150 - loss: 0.5540Processing batch 350
# 399/423 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7159 - loss: 0.5529Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7239 - loss: 0.5450 - val_accuracy: 0.6300 - val_loss: 0.6696
# Epoch 6/50
# Processing batch 0
#  48/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7121 - loss: 0.5516Processing batch 50
# 100/423 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7177 - loss: 0.5479Processing batch 100
# 149/423 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7189 - loss: 0.5470Processing batch 150
# 198/423 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7198 - loss: 0.5462Processing batch 200
# 250/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7209 - loss: 0.5455Processing batch 250
# 298/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7216 - loss: 0.5450Processing batch 300
# 347/423 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7224 - loss: 0.5443Processing batch 350
# 400/423 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7231 - loss: 0.5435Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7297 - loss: 0.5358 - val_accuracy: 0.6331 - val_loss: 0.6592
# Epoch 7/50
# Processing batch 0
#  48/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.7324 - loss: 0.5367Processing batch 50
#  98/423 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.7331 - loss: 0.5352Processing batch 100
# 148/423 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7335 - loss: 0.5344Processing batch 150
# 199/423 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7333 - loss: 0.5340Processing batch 200
# 250/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7332 - loss: 0.5333Processing batch 250
# 299/423 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.7333 - loss: 0.5326Processing batch 300
# 350/423 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7338 - loss: 0.5316Processing batch 350
# 398/423 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7343 - loss: 0.5308Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.7392 - loss: 0.5232 - val_accuracy: 0.6447 - val_loss: 0.6332
# Epoch 8/50
# Processing batch 0
#  49/423 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.