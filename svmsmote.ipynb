# %%
"""
Cross-Project Vulnerability Detection (SVMSMOTE Version)
--------------------------------------------------------
Train on Debian → Test on Chrome
Handles class imbalance using SVMSMOTE
"""

# =========================================================
# Imports
# =========================================================

import os
import random
import warnings
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score,
    recall_score,
    precision_score,
    roc_auc_score,
    f1_score,
    confusion_matrix
)

from xgboost import XGBClassifier

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from keras.callbacks import Callback

from imblearn.over_sampling import SVMSMOTE

warnings.filterwarnings("ignore")

# =========================================================
# TensorFlow Configuration
# =========================================================

os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

tf.config.run_functions_eagerly(True)

tf.config.threading.set_inter_op_parallelism_threads(0)
tf.config.threading.set_intra_op_parallelism_threads(0)

os.environ["OMP_NUM_THREADS"] = "8"

# =========================================================
# Progress Logger
# =========================================================

class BatchLogger(Callback):
    def on_train_batch_begin(self, batch, logs=None):
        if batch % 50 == 0:
            print(f"Processing batch {batch}")

# =========================================================
# Reproducibility
# =========================================================

seed = 42

np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

os.environ["PYTHONHASHSEED"] = str(seed)

# =========================================================
# Original Configuration
# =========================================================

EPOCHS_INITIAL = 50
EPOCHS_RETRAIN = 30

BATCH_SIZE_INITIAL = 64
BATCH_SIZE_RETRAIN = 32

LEARNING_RATE = 1e-5
NUM_ITERATIONS = 3

# =========================================================
# Neural Network
# =========================================================

def create_neural_network(input_dim: int):

    model = Sequential([
        Dense(256, activation="relu", input_dim=input_dim),
        Dropout(0.2),

        Dense(128, activation="relu"),
        Dropout(0.2),

        Dense(64, activation="relu"),
        Dropout(0.2),

        Dense(32, activation="relu"),
        Dropout(0.2),

        Dense(16, activation="relu"),

        Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=Adam(learning_rate=LEARNING_RATE),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# =========================================================
# Semi-supervised Transfer Learning
# =========================================================

def semi_supervised_transfer_learning(x_train, y_train, x_test):

    model = create_neural_network(x_train.shape[1])

    print("\nTraining Neural Network on Debian (SVMSMOTE balanced)...")

    model.fit(
        x_train,
        y_train,
        epochs=EPOCHS_INITIAL,
        batch_size=BATCH_SIZE_INITIAL,
        validation_split=0.2,
        callbacks=[BatchLogger()],
        verbose=1
    )

    print("\nGenerating pseudo labels for Chrome dataset...")

    y_pred = model.predict(x_test, verbose=0)
    y_pred_binary = (y_pred > 0.5).astype(int).flatten()

    x_train_aug = np.concatenate((x_train, x_test))
    y_train_aug = np.concatenate((y_train, y_pred_binary))

    print("\nRetraining model with pseudo-labelled Chrome data...")

    model.fit(
        x_train_aug,
        y_train_aug,
        epochs=EPOCHS_RETRAIN,
        batch_size=BATCH_SIZE_RETRAIN,
        verbose=1
    )

    return model, y_pred.flatten()

# =========================================================
# XGBoost
# =========================================================

def train_base_model_xgb(x_train, y_train):

    model = XGBClassifier(
        n_estimators=100,
        max_depth=3,
        use_label_encoder=False,
        eval_metric="logloss"
    )

    model.fit(x_train, y_train)

    return model

# =========================================================
# Main
# =========================================================

def main():

    print("\n=== Training on Debian → Testing on Chrome (SVMSMOTE) ===")

    # -----------------------------------------------------
    # Load Embeddings
    # -----------------------------------------------------

    deb_emb = np.load("dataset/debian_embeddings.npy")
    deb_lbl = np.load("dataset/debian_labels.npy")

    chr_emb = np.load("dataset/chrome_embeddings.npy")
    chr_lbl = np.load("dataset/chrome_labels.npy")

    deb_emb = deb_emb.astype(np.float32)
    chr_emb = chr_emb.astype(np.float32)

    deb_lbl = deb_lbl.astype(np.float32)
    chr_lbl = chr_lbl.astype(np.float32)

    print("Debian dataset shape:", deb_emb.shape)
    print("Chrome dataset shape:", chr_emb.shape)

    # -----------------------------------------------------
    # Normalize
    # -----------------------------------------------------

    scaler = StandardScaler()
    deb_emb = scaler.fit_transform(deb_emb)
    chr_emb = scaler.transform(chr_emb)

    # -----------------------------------------------------
    # Apply SVMSMOTE
    # -----------------------------------------------------

    print("\nApplying SVMSMOTE to balance Debian dataset...")

    svm_smote = SVMSMOTE(random_state=seed)
    deb_emb_balanced, deb_lbl_balanced = svm_smote.fit_resample(
        deb_emb,
        deb_lbl
    )

    print("After SVMSMOTE:", deb_emb_balanced.shape)

    # -----------------------------------------------------
    # Ensemble Training
    # -----------------------------------------------------

    ensemble_predictions = np.zeros(len(chr_lbl))

    for i in range(NUM_ITERATIONS):

        print(f"\n=== Ensemble Iteration {i+1}/{NUM_ITERATIONS} ===")

        model_nn, _ = semi_supervised_transfer_learning(
            deb_emb_balanced,
            deb_lbl_balanced,
            chr_emb
        )

        print("\nTraining XGBoost model...")

        model_xgb = train_base_model_xgb(
            deb_emb_balanced,
            deb_lbl_balanced
        )

        print("Predicting Chrome dataset...")

        model_xgb_pred = model_xgb.predict(chr_emb)

        ensemble_predictions += model_xgb_pred

    # -----------------------------------------------------
    # Average Predictions
    # -----------------------------------------------------

    ensemble_avg = ensemble_predictions / NUM_ITERATIONS
    y_pred_final = (ensemble_avg > 0.5).astype(int)

    # -----------------------------------------------------
    # Metrics
    # -----------------------------------------------------

    accuracy = accuracy_score(chr_lbl, y_pred_final)
    recall = recall_score(chr_lbl, y_pred_final)
    precision = precision_score(chr_lbl, y_pred_final)
    auc = roc_auc_score(chr_lbl, ensemble_avg)
    f1 = f1_score(chr_lbl, y_pred_final)

    tn, fp, fn, tp = confusion_matrix(chr_lbl, y_pred_final).ravel()
    g_mean = np.sqrt(tp / (tp + fn))
    pf = fp / (fp + tn)

    print("\n=== Evaluation Results (Chrome Test Set) ===")
    print(f"Accuracy:  {accuracy:.3f}")
    print(f"Precision: {precision:.3f}")
    print(f"Recall:    {recall:.3f}")
    print(f"F1-score:  {f1:.3f}")
    print(f"AUC:       {auc:.3f}")
    print(f"G-mean:    {g_mean:.3f}")
    print(f"PF value:  {pf:.3f}")

    print("\nConfusion Matrix:")
    print(f"TN: {tn}")
    print(f"FP: {fp}")
    print(f"FN: {fn}")
    print(f"TP: {tp}")

    # -----------------------------------------------------
    # Plot Confusion Matrix
    # -----------------------------------------------------

    cm = confusion_matrix(chr_lbl, y_pred_final)

    plt.figure(figsize=(6, 5))
    plt.imshow(cm, interpolation="nearest")
    plt.title("Confusion Matrix (Chrome Test Set)")
    plt.colorbar()

    tick_marks = np.arange(2)
    plt.xticks(tick_marks, ["Non-Vulnerable", "Vulnerable"])
━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8944 - loss: 0.2727Processing batch 200
# 249/423 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.8948 - loss: 0.2723Processing batch 250
# 300/423 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8952 - loss: 0.2719Processing batch 300
# 349/423 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8955 - loss: 0.2717Processing batch 350
# 400/423 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8958 - loss: 0.2714Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.8988 - loss: 0.2684 - val_accuracy: 0.9600 - val_loss: 0.1838
# Epoch 49/50
# Processing batch 0
#  49/423 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.8836 - loss: 0.2920Processing batch 50
#  99/423 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8886 - loss: 0.2830Processing batch 100
# 150/423 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8914 - loss: 0.2779Processing batch 150
# 199/423 ━━━━━━━━━━━━━━━━━━━━ 4s 21ms/step - accuracy: 0.8928 - loss: 0.2758Processing batch 200
# 249/423 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.8937 - loss: 0.2744Processing batch 250
# 299/423 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.8944 - loss: 0.2734Processing batch 300
# 350/423 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8948 - loss: 0.2726Processing batch 350
# 400/423 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8953 - loss: 0.2719Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8993 - loss: 0.2654 - val_accuracy: 0.9615 - val_loss: 0.1802
# Epoch 50/50
# Processing batch 0
#  50/423 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.8989 - loss: 0.2708Processing batch 50
#  99/423 ━━━━━━━━━━━━━━━━━━━━ 7s 24ms/step - accuracy: 0.8985 - loss: 0.2683Processing batch 100
# 150/423 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8989 - loss: 0.2665Processing batch 150
# 200/423 ━━━━━━━━━━━━━━━━━━━━ 5s 24ms/step - accuracy: 0.8988 - loss: 0.2664Processing batch 200
# 249/423 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - accuracy: 0.8988 - loss: 0.2667Processing batch 250
# 298/423 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.8989 - loss: 0.2667Processing batch 300
# 348/423 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.8988 - loss: 0.2667Processing batch 350
# 399/423 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8988 - loss: 0.2667Processing batch 400
# 423/423 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8992 - loss: 0.2656 - val_accuracy: 0.9594 - val_loss: 0.1837
#
# Generating pseudo labels for Chrome dataset...
#
# Retraining model with pseudo-labelled Chrome data...
# Epoch 1/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 28s 24ms/step - accuracy: 0.9195 - loss: 0.2291
# Epoch 2/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 29s 24ms/step - accuracy: 0.9237 - loss: 0.2179
# Epoch 3/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 26s 22ms/step - accuracy: 0.9267 - loss: 0.2144
# Epoch 4/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9282 - loss: 0.2092
# Epoch 5/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9296 - loss: 0.2044
# Epoch 6/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - accuracy: 0.9317 - loss: 0.1993
# Epoch 7/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9331 - loss: 0.1968
# Epoch 8/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9320 - loss: 0.1955
# Epoch 9/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9346 - loss: 0.1916
# Epoch 10/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9365 - loss: 0.1872
# Epoch 11/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9373 - loss: 0.1860
# Epoch 12/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9385 - loss: 0.1826
# Epoch 13/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9408 - loss: 0.1802
# Epoch 14/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9408 - loss: 0.1783
# Epoch 15/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9415 - loss: 0.1745
# Epoch 16/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9414 - loss: 0.1754
# Epoch 17/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9428 - loss: 0.1707
# Epoch 18/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9436 - loss: 0.1738
# Epoch 19/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9446 - loss: 0.1702
# Epoch 20/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9455 - loss: 0.1666
# Epoch 21/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9450 - loss: 0.1656
# Epoch 22/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9466 - loss: 0.1651
# Epoch 23/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9464 - loss: 0.1618
# Epoch 24/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9477 - loss: 0.1602
# Epoch 25/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9473 - loss: 0.1586
# Epoch 26/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9489 - loss: 0.1565
# Epoch 27/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9494 - loss: 0.1570
# Epoch 28/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9500 - loss: 0.1556
# Epoch 29/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - accuracy: 0.9507 - loss: 0.1512
# Epoch 30/30
# 1194/1194 ━━━━━━━━━━━━━━━━━━━━ 25s 21ms/step - accuracy: 0.9499 - loss: 0.1546
#
# Training XGBoost model...
# Predicting Chrome dataset...
#
# === Evaluation Results (Chrome Test Set) ===
# Accuracy:  0.773
# Precision: 0.253
# Recall:    0.114
# F1-score:  0.157
# AUC:       0.519
# G-mean:    0.338
# PF value:  0.077
#
# Confusion Matrix:
# TN: 3334
# FP: 277
# FN: 731
# TP: 94
